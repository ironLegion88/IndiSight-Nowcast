# %% [markdown]
# # Model Training
# Train XGBoost and Deep Learning models for nowcasting

# %%
import xgboost as xgb
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# TODO: Load processed data
# TODO: Train XGBoost model
# TODO: Train ResNet/ViT for satellite embeddings
