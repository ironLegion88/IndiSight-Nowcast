# %% [markdown]
# # Satellite Data Extraction
# Extract satellite imagery and embeddings from Google Earth Engine

# %%
import ee
import numpy as np
from datetime import datetime

# Initialize Google Earth Engine
# ee.Authenticate()
# ee.Initialize()

# TODO: Extract satellite imagery and compute embeddings
