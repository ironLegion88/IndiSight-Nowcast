# %% [markdown]
# # NDAP EDA
# Exploratory Data Analysis for NDAP CSVs and GeoJSONs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load and explore NDAP data
# TODO: Load raw NDAP CSVs
